# %% [markdown]
# <a href="https://colab.research.google.com/github/kadesole22/Homework_4/blob/main/HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
data = pd.read_csv("diabetes_train.csv")
print(data)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 753     0   181    88    44   510  43.3  0.222   26  tested_positive
# 754     8   154    78    32     0  32.4  0.443   45  tested_positive
# 755     1   128    88    39   110  36.5  1.057   37  tested_positive
# 756     7   137    90    41     0  32.0  0.391   39  tested_negative
# 757     0   123    72     0     0  36.3  0.258   52  tested_positive
#
# [758 rows x 9 columns]

# %%
X = data.drop("class", axis=1)
y = data["class"]

# 3. Split the data into train and test sets (10% test size)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.0132, random_state=42, stratify=y
)

# 4. Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 5. Train SVM
clf = svm.SVC(kernel="rbf", C=1.0, gamma="scale")
clf.fit(X_train_scaled, y_train)

# 6. Predict on test set
predictions = clf.predict(X_test_scaled)

print("Predictions:")
print(predictions)

print("\nActual values:")
print(y_test.values)
# Out:
# Predictions:
# ['tested_negative' 'tested_positive' 'tested_positive' 'tested_negative'
#  'tested_positive' 'tested_negative' 'tested_negative' 'tested_negative'
#  'tested_negative' 'tested_positive' 'tested_negative']
#
# Actual values:
# ['tested_positive' 'tested_positive' 'tested_positive' 'tested_negative'
#  'tested_negative' 'tested_negative' 'tested_positive' 'tested_negative'
#  'tested_negative' 'tested_negative' 'tested_negative']
